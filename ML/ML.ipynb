# %% [markdown]
# # LECTURE 1 date: 02.09.2021
#
# ## **Искуственный Интеллект**
#
# ### AI > ML > NeuroNet > DeepL
#
# ### **Математика в ML**:
#
# Предмет|%
# -|-
# ЛинАлг|35%
# ТерВер и МатСтат|25%
# Матан|15%
# ЛинАлг|35%
# Алгоритмы|15%
# DataPreprocessing|10%
#
# ### Составляющие обучения
#
# 1. Данные
# 2. Признаки
# 3. Алгоритм
#
# ### ! Карта ML
#
# ### Генетические алгоритмы - процессы м оценкой значимости каждой особи и применяет мутации, чтобы понять изменения - в лучшую или худшую.

# %% [markdown]
# # LECTURE 2 date: 09.09.2021
#
# ### Виды нейронок
#
# ### **Реккурентные**. Помогают достраивать тексты, изображения, даже код.
#
# ### В отличие от обычного машиноного обучения, где есть необходииость выделения базовых объектов для наблюдения(пинг-понг), ИИ избавляет нас от такой необходимости
#
# ### Гифка с машинками. ИИ дает приоритет боле успешным машинкам

# %% [markdown]
# # PRACTICE 4 date: 28.09.2021
#
# ### K-means
